# %%
import pandas as pd
from sklearn.metrics import accuracy_score
import pandas as pd 
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn import tree
import joblib 
from sklearn.tree import export_graphviz
import graphviz
import yfinance as yf
import matplotlib.pyplot as plt
from datetime import datetime

# %%
file = 'data.csv'
ticker = 'AAPL'

data = pd.read_csv(file)

try:
    data['date'] = data['date'].apply(lambda x: float(x.split()[0].replace('-', '')))
    
except:
    print('<-----Could not convert string to float----->')

x_values = data.drop(columns=['volume','Name','date'])
y = data['volume']

x_train, x_test, y_train, y_test = train_test_split(x_values, y, test_size=0.0005)

# %%
model = DecisionTreeClassifier ()
model.fit (x_train, y_train)
                
#test for music.csv
#predictions = model.predict([[21 = age, 1 = gender]])

predictions = model.predict (x_test)
error = 0.10 * predictions
score = accuracy_score(y_test, predictions)

results_df = pd.DataFrame({
    'Real Numbers': y_test,
    'Predictions': predictions - error 
})

try:
    import matplotlib.pyplot as plt
    ax = results_df.plot(kind='bar', figsize=(10, 6), legend=True)
    plt.title('Real Numbers vs Predictions')
    plt.xlabel('Volumes')  # Empty string to remove x-axis label
    plt.ylabel('Values')
    plt.xticks([])  # Empty list to remove x-axis tick labels
    plt.legend(loc='upper right')

    # Format y-axis labels with two decimal places
    ax.yaxis.set_major_formatter(plt.FuncFormatter(lambda x, _: '{:.2f}'.format(x)))
    plt.show()
    

except:
    print('<-----Could not Visualize the data----->')

# %%
#joblib.dump (model, 'model_trained.joblib')
print(results_df)
# Out:
#       Real Numbers  Predictions
# 1097      32541404   26270959.5

# %%
#to load the model
#model = joblib.load(model_trained.joblib')

# %%
# Get the data
data = yf.download(ticker, '1980-12-12', '2023-11-17')


# Plot adjusted close price data
# %matplotlib inline
data['Volume'].plot()
plt.show()
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
print("The Test Datas: \n",
     x_test)
# Out:
# The Test Datas:
#       open     high   low  close
# 762  96.0  96.7599  95.8  96.04
